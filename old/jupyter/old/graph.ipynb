# %% [markdown]
# # Plot a graph of selected features

# %%
import pandas as pd

# %%
df = pd.read_csv('standard_stats_big5.csv', index_col=0)
df.head()
# Out:
#               Player   Nation    Pos           Squad                Comp  \
# 0         Max Aarons  eng ENG     DF     Bournemouth  eng Premier League
# 1   Brenden Aaronson   us USA  MF,FW    Union Berlin       de Bundesliga
# 2    Paxten Aaronson   us USA     MF  Eint Frankfurt       de Bundesliga
# 3  Keyliane Abdallah   fr FRA     FW       Marseille          fr Ligue 1
# 4   Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
#
#     Age    Born  MP  Starts   Min  ...  Gls-90  Ast-90  G+A-90  G-PK-90  \
# 0  23.0  2000.0  20      13  1237  ...    0.00    0.07    0.07     0.00
# 1  22.0  2000.0  30      14  1267  ...    0.14    0.14    0.28     0.14
# 2  19.0  2003.0   7       1   101  ...    0.00    0.89    0.89     0.00
# 3  17.0  2006.0   1       0     4  ...    0.00    0.00    0.00     0.00
# 4  35.0  1987.0  31      31  2781  ...    0.13    0.00    0.13     0.10
#
#    G+A-PK  xG-90  xAG-90  xG+xAG  npxG-90  npxG+xAG-90
# ...
