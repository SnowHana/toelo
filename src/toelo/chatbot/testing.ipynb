# %%
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import create_react_agent


from toelo.chatbot.chatbot import BaseChatBot

# %%
b = BaseChatBot("qwen")
# Out:
# Initialising with model : qwen3:8b

# %%
b.llm.invoke("hi")
# Out:
# AIMessage(content='<think>\nOkay, the user just said "hi". That\'s a friendly greeting. I should respond in a warm and welcoming manner. Let me make sure to acknowledge their greeting and offer assistance. Maybe add an emoji to keep it friendly. Keep it simple and open-ended so they feel comfortable to ask anything. Let me check for any typos or errors. Yep, that looks good. Ready to respond.\n</think>\n\nHello! 😊 How can I assist you today? Let me know if you need help with anything!', additional_kwargs={}, response_metadata={'model': 'qwen3:8b', 'created_at': '2025-06-12T13:26:22.224567374Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23907129127, 'load_duration': 6907278085, 'prompt_eval_count': 9, 'prompt_eval_duration': 879115517, 'eval_count': 106, 'eval_duration': 16119647535, 'model_name': 'qwen3:8b'}, id='run--5d23a5c9-ac82-4fbf-a866-190cb5d9a418-0', usage_metadata={'input_tokens': 9, 'output_tokens': 106, 'total_tokens': 115})

# %%
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import create_react_agent


from toelo.chatbot.chatbot import BaseChatBot


class AgentChatBot(BaseChatBot):
    """Use langsmith tools

    Args:
        BaseChatBot (_type_): _description_
    """

    def __init__(self, chatbot_name: str):
        super().__init__(chatbot_choice=chatbot_name)
        toolkit = SQLDatabaseToolkit(db=self.db, llm=self.llm)
        self.tools = toolkit.get_tools()

        self._init_system_message()
        self._init_agent_executor()

    def _init_system_message(self):

        self.system_message = """
        You are an agent designed to interact with a SQL database.
        Given an input question, create a syntactically correct {dialect} query to run,
        then look at the results of the query and return the answer. Unless the user
        specifies a specific number of examples they wish to obtain, always limit your
        query to at most {top_k} results.

        You can order the results by a relevant column to return the most interesting
        examples in the database. Never query for all the columns from a specific table,
        only ask for the relevant columns given the question.

        You MUST double check your query before executing it. If you get an error while
        executing a query, rewrite the query and try again.

        DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the
        database.


        Below is the description of tools available.

        sql_db_query: Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.

        sql_db_schema: Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3

        sql_db_list_tables: Input is an empty string, output is a comma-separated list of tables in the database.

        sql_db_query_checker: Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!



        To start you should ALWAYS look at the tables in the database to see what you
        can query. Do NOT skip this step.

        You can use sql_db_list_tables to list all the tables and use sql_db_schema to see the schema and sample rows for those tables.

        Then you should query the schema of the most relevant tables.
        """.format(
            dialect=self.db.dialect,
            top_k=5,
        )

    def _init_agent_executor(self):
        # Init agent
        self.agent_executor = create_react_agent(
            self.llm, self.tools, prompt=self.system_message
        )

    def ask_question(self, question: str):
        res = []
        for step in self.agent_executor.stream(
            {"messages": [{"role": "user", "content": question}]}, stream_mode="values"
        ):
            messages = step["messages"][-1].pretty_repr()
            res.append(messages)
        return res

# %%
a = AgentChatBot("llama")
# Out:
# Initialising with model : qwen3:8b

# %%
a.ask_question("hi")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a.ask_question("hi")
#
# Cell In[4], line 75, in AgentChatBot.ask_question(self, question)
#      73 def ask_question(self, question: str):
#      74     res = []
# ---> 75     for step in self.agent_executor.stream(
#      76         {"messages": [{"role": "user", "content": question}]}, stream_mode="values"
#      77     ):
#      78         messages = step["messages"][-1].pretty_repr()
#      79         res.append(messages)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:161, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     159 t = tasks[0]
#     160 try:
# --> 161     run_with_retry(
#     162         t,
#     163         retry_policy,
#     164         configurable={
#     165             CONFIG_KEY_CALL: partial(
#     166                 _call,
#     167                 weakref.ref(t),
#     168                 retry=retry_policy,
#     169                 futures=weakref.ref(futures),
#     170                 schedule_task=schedule_task,
#     171                 submit=self.submit,
#     172             ),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:370, in RunnableCallable.invoke(self, input, config, **kwargs)
#     368     # run in context
#     369     with set_config_context(child_config, run) as context:
# --> 370         ret = context.run(self.func, *args, **kwargs)
#     371 except BaseException as e:
#     372     run_manager.on_chain_error(e)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langgraph/prebuilt/chat_agent_executor.py:505, in create_react_agent.<locals>.call_model(state, config)
#     503 def call_model(state: StateSchema, config: RunnableConfig) -> StateSchema:
#     504     state = _get_model_input_state(state)
# --> 505     response = cast(AIMessage, model_runnable.invoke(state, config))
#     506     # add agent name to the AIMessage
#     507     response.name = name
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5430, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5423 @override
#    5424 def invoke(
#    5425     self,
#    (...)
#    5428     **kwargs: Optional[Any],
#    5429 ) -> Output:
# -> 5430     return self.bound.invoke(
#    5431         input,
#    5432         self._merge_configs(config),
#    5433         **{**self.kwargs, **kwargs},
#    5434     )
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:741, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     734 def _generate(
#     735     self,
#     736     messages: list[BaseMessage],
#    (...)
#     739     **kwargs: Any,
#     740 ) -> ChatResult:
# --> 741     final_chunk = self._chat_stream_with_aggregation(
#     742         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     743     )
#     744     generation_info = final_chunk.generation_info
#     745     chat_generation = ChatGeneration(
#     746         message=AIMessage(
#     747             content=final_chunk.text,
#    (...)
#     752         generation_info=generation_info,
#     753     )
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:678, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     669 def _chat_stream_with_aggregation(
#     670     self,
#     671     messages: list[BaseMessage],
#    (...)
#     675     **kwargs: Any,
#     676 ) -> ChatGenerationChunk:
#     677     final_chunk = None
# --> 678     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     679         if final_chunk is None:
#     680             final_chunk = chunk
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:763, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     756 def _iterate_over_stream(
#     757     self,
#     758     messages: list[BaseMessage],
#     759     stop: Optional[list[str]] = None,
#     760     **kwargs: Any,
#     761 ) -> Iterator[ChatGenerationChunk]:
#     762     is_thinking = False
# --> 763     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     764         if not isinstance(stream_resp, str):
#     765             if stream_resp.get("done") is True:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/langchain_ollama/chat_models.py:665, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     662 chat_params = self._chat_params(messages, stop, **kwargs)
#     664 if chat_params["stream"]:
# --> 665     yield from self._client.chat(**chat_params)
#     666 else:
#     667     yield self._client.chat(**chat_params)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/ollama/_client.py:172, in Client._request.<locals>.inner()
#     169   e.response.read()
#     170   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 172 for line in r.iter_lines():
#     173   part = json.loads(line)
#     174   if err := part.get('error'):
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_models.py:863, in Response.iter_lines(self)
#     861 decoder = LineDecoder()
#     862 with request_context(request=self._request):
# --> 863     for text in self.iter_text():
#     864         for line in decoder.decode(text):
#     865             yield line
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_models.py:850, in Response.iter_text(self, chunk_size)
#     848 chunker = TextChunker(chunk_size=chunk_size)
#     849 with request_context(request=self._request):
# --> 850     for byte_content in self.iter_bytes():
#     851         text_content = decoder.decode(byte_content)
#     852         for chunk in chunker.decode(text_content):
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_models.py:831, in Response.iter_bytes(self, chunk_size)
#     829 chunker = ByteChunker(chunk_size=chunk_size)
#     830 with request_context(request=self._request):
# --> 831     for raw_bytes in self.iter_raw():
#     832         decoded = decoder.decode(raw_bytes)
#     833         for chunk in chunker.decode(decoded):
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_models.py:885, in Response.iter_raw(self, chunk_size)
#     882 chunker = ByteChunker(chunk_size=chunk_size)
#     884 with request_context(request=self._request):
# --> 885     for raw_stream_bytes in self.stream:
#     886         self._num_bytes_downloaded += len(raw_stream_bytes)
#     887         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_client.py:127, in BoundSyncStream.__iter__(self)
#     126 def __iter__(self) -> typing.Iterator[bytes]:
# --> 127     for chunk in self._stream:
#     128         yield chunk
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:116, in ResponseStream.__iter__(self)
#     114 def __iter__(self) -> typing.Iterator[bytes]:
#     115     with map_httpcore_exceptions():
# --> 116         for part in self._httpcore_stream:
#     117             yield part
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:367, in PoolByteStream.__iter__(self)
#     365 except BaseException as exc:
#     366     self.close()
# --> 367     raise exc from None
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:363, in PoolByteStream.__iter__(self)
#     361 def __iter__(self) -> Iterator[bytes]:
#     362     try:
# --> 363         for part in self._stream:
#     364             yield part
#     365     except BaseException as exc:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:349, in HTTP11ConnectionByteStream.__iter__(self)
#     347 with ShieldCancellation():
#     348     self.close()
# --> 349 raise exc
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:341, in HTTP11ConnectionByteStream.__iter__(self)
#     339 try:
#     340     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 341         for chunk in self._connection._receive_response_body(**kwargs):
#     342             yield chunk
#     343 except BaseException as exc:
#     344     # If we get an exception while streaming the response,
#     345     # we want to close the response (and possibly the connection)
#     346     # before raising that exception.
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:210, in HTTP11Connection._receive_response_body(self, request)
#     207 timeout = timeouts.get("read", None)
#     209 while True:
# --> 210     event = self._receive_event(timeout=timeout)
#     211     if isinstance(event, h11.Data):
#     212         yield bytes(event.data)
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/toelo/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
